# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from src.data_generator import TwoAFCGenerator  
from src.utils import plot_two_afc_batches

# %%
gen = TwoAFCGenerator(batch_size=64,
                      fix_dur=10,
                      stim_dur=20,
                      delay_dur=5,
                      decision_dur=5,
                      min_diff=0.1,
                      max_diff=0.6,
                      noise_level=0.3)
x, y = gen()

# %%
print(x.shape, y.shape)
# Out:
# torch.Size([40, 64, 3]) torch.Size([40, 64])

# %%
plot_two_afc_batches(gen, num_trials=3)
